# %%
import webbrowser
import time

urls = [
    "https://data-sagis.opendata.arcgis.com/",
    "https://hub.arcgis.com/api/v3/datasets/4468534af02640768b2038f0c2d080d8_27/downloads/data?format=csv&spatialRefId=2239&where=1%3D1",
    "https://data-sagis.opendata.arcgis.com/datasets/4782df29c0d944a1b453aad1f9e475dd_9/explore?location=31.970700%2C-81.071600%2C9",
    "https://data-sagis.opendata.arcgis.com/datasets/f8b4d6f31fb0429bba44b0fdd846d281_10/explore?location=31.970700%2C-81.071600%2C9",
    "https://data-sagis.opendata.arcgis.com/search?tags=boundaries",
    "https://data-sagis.opendata.arcgis.com/maps/4782df29c0d944a1b453aad1f9e475dd",
    "https://data-sagis.opendata.arcgis.com/datasets/91afc56e031b49a19af2b98a2cedb51f_11/explore?location=31.996909%2C-81.018042%2C11",
    "https://data-sagis.opendata.arcgis.com/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/explore?location=32.041349%2C-81.136602%2C10",
    "https://hub.arcgis.com/api/v3/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/downloads/data?format=shp&spatialRefId=2239&where=1%3D1",
    "https://hub.arcgis.com/api/v3/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/downloads/data?format=csv&spatialRefId=2239&where=1%3D1",
    "https://hub.arcgis.com/api/v3/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/downloads/data?format=geojson&spatialRefId=4326&where=1%3D1",
    "https://hub.arcgis.com/api/v3/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/downloads/data?format=kml&spatialRefId=4326&where=1%3D1",
    "",
    "",
        
]

for url in urls:
    print(f"Opening: {url}")
    webbrowser.open(url)
    time.sleep(0.5)  # small delay so your browser doesn't choke
# Out:
# Opening: https://data-sagis.opendata.arcgis.com/
# Opening: https://hub.arcgis.com/api/v3/datasets/4468534af02640768b2038f0c2d080d8_27/downloads/data?format=csv&spatialRefId=2239&where=1%3D1
# Opening: https://data-sagis.opendata.arcgis.com/datasets/4782df29c0d944a1b453aad1f9e475dd_9/explore?location=31.970700%2C-81.071600%2C9
# Opening: https://data-sagis.opendata.arcgis.com/datasets/f8b4d6f31fb0429bba44b0fdd846d281_10/explore?location=31.970700%2C-81.071600%2C9
# Opening: https://data-sagis.opendata.arcgis.com/search?tags=boundaries
# Opening: https://data-sagis.opendata.arcgis.com/maps/4782df29c0d944a1b453aad1f9e475dd
# Opening: https://data-sagis.opendata.arcgis.com/datasets/91afc56e031b49a19af2b98a2cedb51f_11/explore?location=31.996909%2C-81.018042%2C11
# Opening: https://data-sagis.opendata.arcgis.com/datasets/9f9bde000ced4a1b88f2f9cc185b7a29_6/explore?location=32.041349%2C-81.136602%2C10
