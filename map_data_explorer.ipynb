# %%
import os

base = r"data_files\parcels"

for root, dirs, files in os.walk(base):
    for f in files:
        print(os.path.join(root, f))
# Out:
# data_files\parcels\Aldermanic_Districts_(Savannah)_.zip
# data_files\parcels\Parcel_Digest_2025.csv
# data_files\parcels\Parcel_Digest_2025.zip
# data_files\parcels\School_Board_Districts.zip
# data_files\parcels\Chatham_Wetlands_(NWI)\Chatham_Wetlands_(NWI).cpg
# data_files\parcels\Chatham_Wetlands_(NWI)\Chatham_Wetlands_(NWI).dbf
# data_files\parcels\Chatham_Wetlands_(NWI)\Chatham_Wetlands_(NWI).prj
# data_files\parcels\Chatham_Wetlands_(NWI)\Chatham_Wetlands_(NWI).shp
# data_files\parcels\Chatham_Wetlands_(NWI)\Chatham_Wetlands_(NWI).shx
# data_files\parcels\jurisdictions\Municipality.csv
# data_files\parcels\jurisdictions\Municipality.geojson
# data_files\parcels\jurisdictions\Municipality.kml
# data_files\parcels\jurisdictions\Municipality.zip
# data_files\parcels\jurisdictions\Municipality\Municipality.cpg
# data_files\parcels\jurisdictions\Municipality\Municipality.dbf
# data_files\parcels\jurisdictions\Municipality\Municipality.prj
# ...
